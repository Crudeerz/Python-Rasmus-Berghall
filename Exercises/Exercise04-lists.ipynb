# %% [markdown]
# # List exercises

# %% [markdown]
# ## 1. Dice rolls
#
# ## 1. Dice rolls (*)
#
# Simulate 10 dice rolls and **append** the rolls to a list or use **list comprehension**.
#
# &nbsp; a) &nbsp; sort the list in **ascending** order (*)
#
# &nbsp; b) &nbsp; sort the list in **descending** order (*)
#
# &nbsp; c) &nbsp; find the **maximum** and **minimum** value in the list (*)

# %%
import random

rolls = []

while len(rolls) < 10:
    dice = random.randint(1,6)
    rolls.append(dice)

print(f"Original list: {rolls}")
rolls.sort()
print(f"a) Sorted in ascending order: {rolls}")
rolls.sort(reverse=True)
print(f"b) Sorted in descending order: {rolls}")
print(f"Max value: {max(rolls)}, Min value: {min(rolls)}.")
# Out:
# Original list: [5, 1, 4, 3, 1, 2, 6, 5, 1, 3]
# a) Sorted in ascending order: [1, 1, 1, 2, 3, 3, 4, 5, 5, 6]
# b) Sorted in descending order: [6, 5, 5, 4, 3, 3, 2, 1, 1, 1]
# Max value: 6, Min value: 1.

# %% [markdown]
# ## 2. Food Menu
#
# Create a:
#
# &nbsp; a) &nbsp; **list** with the following elements: "vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor". (*)
#
# &nbsp; b) &nbsp; **list** with the weekdays (*)
#
# &nbsp; c) &nbsp; create a food menu with each day corresponding to each food item and print it out. (*)

# %%
food_list = ["vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor"]
weekdays = ["måndag", "tisdag", "onsdag", "torsdag", "fredag"]
food_menu = []
i = 0

weekdays = [day.capitalize() for day in weekdays]
food_list = [food.capitalize() for food in food_list]

'''
for day in weekdays:
    food_menu.append(f"{day}:")
    food_menu.append(f"{food_list[i]}")
    i += 1
'''

while i < len(food_list):
    food_menu.append(f"{weekdays[i]}: {food_list[i]}")
    i += 1


for food in food_menu:
    print(f"{food}")
# Out:
# Måndag: Vegetarisk lasagne
# Tisdag: Spaghetti
# Onsdag: Fisk
# Torsdag: Grönsakssoppa
# Fredag: Pannkakor

# %% [markdown]
# ## 3. Squares (*)
#
# &nbsp; a) &nbsp; Use **list comprehension** to create a list of squares from -10 to 10 (*)
#
# &nbsp; a) &nbsp; Plot this list using **matplotlib**. (*)

# %%
import matplotlib.pyplot as plt


squares = [square for square in range(-10,11)]
squares

plt.plot(squares)

# %% [markdown]
# ## 4. Chessboard (**)
#
# &nbsp; a) &nbsp; Create this list using **list comprehension**: (*)
#
# ```python
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ```
#
# &nbsp; b) &nbsp; Create a 2D list to hold the coordinates in a chessboard. (**)

# %%
letters = 'ABCDEFGH'

### a) ###
list = [letter + '1' for letter in letters]
print(list)

### b) ###
# List comprehension:
chess_board = [[x + str(i) for x in letters] for i in range(1,9)]

for item in chess_board:
    print(item)

print()
print(chess_board)
# Out:
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2']
# ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3']
# ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4']
# ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5']
# ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6']
# ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7']
# ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']
#
# [['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1'], ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2'], ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3'], ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4'], ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5'], ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6'], ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7'], ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']]

# %%
#Using while loop:

chess_board = []
while i <= len(list):
    list = [letter + str(i) for letter in letters]
    i += 1
    chess_board.append(f"{list}")
print(chess_board)
print()


for item in chess_board:
    print(f"{item}")
# Out:
# ["['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']", "['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2']", "['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3']", "['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4']", "['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5']", "['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6']", "['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7']", "['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']"]
#
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2']
# ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3']
# ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4']
# ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5']
# ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6']
# ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7']
# ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']

# %% [markdown]
# ## 5. Dice rolls convergence (**)
#
# Simulate:
#
# &nbsp; a) &nbsp; 100 dice rolls and count the number of outcome six. (*)
#
# &nbsp; b) &nbsp; 10, 100, 1000, 10000, 100000, 1000000 dice rolls. Count the number of outcome six in each simulation and store it in a list. Compute the probability of outcome six in each simulation. (**)
#
# &nbsp; c) &nbsp; Use matplotlib to plot this list. (*)

# %%
### a) ###
import random

dice_rolls = [random.randint(1,6) for x in range(100)]
#print(dice_rolls.count(6))

result = []
prob = []
i = 10
while i < 1000001:
    dice_rolls = [random.randint(1,6) for x in range(i)]
    result.append(dice_rolls.count(6))
    prob.append(dice_rolls.count(6)/i)
    i *= 10
print(result)
print(prob)

plt.plot(prob, '-*')
plt.xlabel('Number of dice roll sequence')
plt.ylabel('Probability')
# Out:
# [0, 20, 167, 1686, 16572, 166393]
# [0.0, 0.2, 0.167, 0.1686, 0.16572, 0.166393]
# Text(0, 0.5, 'Probability')

# %% [markdown]
# # 6. Monte Carlo simulation
#
# a) Simulate 5000 uniformly distributed points between -1 and 1, $X\sim U(-1,1)$. Now calculate the Euclidean distances between each point and the origin (0,0), $d_i = \sqrt{x_i^2 + y_i^2}$. For $d_i < 1$ plot the point with one color, and for $d_i > 1$ plot the point in another color, $i = \{1,\ldots, 5000\}$.  (**)
#
# b) Calculate the fraction between number of inner points and number of outer points. What do you this will converge to when number of points reaches infinity? (**)

# %%
randomlist = [random.uniform(-1,1) for x in range(5000)]
print(randomlist)
# Out:
# [0.5133912849846229, -0.7524515719581608, -0.15888569988422185, -0.11624938024465137, 0.17991963276633371, -0.18418836981105535, 0.4490415683756832, 0.3726316408370012, -0.14717149130893725, 0.9032451345514754, -0.8193753130582166, -0.46993933949711986, 0.7672939671478092, 0.11643814506042349, 0.17580300679863714, 0.5746312404645024, 0.8691521885706399, 0.26140135927675745, 0.4561648812194017, -0.22155241292878958, -0.6433785478998091, 0.37338609133238476, -0.8441696570300785, -0.14865758151795494, 0.28046548841762675, -0.2093042758496675, -0.9107495500570395, -0.49009530757448827, 0.3034047860069904, -0.4058621501665405, 0.5063565865015207, 0.14938856321960836, 0.7461868389001669, 0.5044432530190692, 0.7286697829297595, -0.8751485915101642, -0.32157992268515634, 0.018115681825629615, 0.652346920518079, 0.44682339374832325, -0.022261076269895375, 0.9325391400027807, 0.49598934272668327, -0.4608748879801985, 0.9533401296136503, -0.7767973397291708, -0.5424244588500833, -0.22691964654591756, 0.6501155731508621, 0.05657865280579366, -0.8524753042221502, -0.9687693276622631, 0.9728735971290214, 0.9846542137874301, -0.46578316381814977, -0.3615119827982207, 0.31832800946089135,